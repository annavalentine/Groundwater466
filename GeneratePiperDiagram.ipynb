# %%
import abstraction as A

# %%
##Be sure to run cell above to bring in library that makes calculations! 
## INPUTS GO HERE 

#Alkalinity (mg/L)
Ca = 1
Mg = 1
Na = 550
K  = 3.5

#Hardness (mg/L)
SO4 = 59
HCO3 = 1315
CO3 = 100
Cl = 45

# %%
A.plot_piper(Ca, Mg, Na, K, SO4, HCO3, CO3, Cl)
